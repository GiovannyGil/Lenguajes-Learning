# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="darkgrid") # estilo a seaborn

df = sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# grafico de barras, por propinas promedio por sexo

sns.barplot(data=df, x="sex", y="tip", errorbar=None)
plt.title("Propinas promedio por sexo")

#Hombres, en promedio, pagan más propinas
# Out:
# Text(0.5, 1.0, 'Propinas promedio por sexo')

# %%
sns.barplot(data=df, x="day", y="tip", errorbar=None)
plt.title("Propimas promedio por dia")

# Los DOMINGOS se paga más propinas
# Out:
# Text(0.5, 1.0, 'Propimas promedio por dia')

# %%
sns.barplot(data=df, x="time", y="tip", errorbar=None)
plt.title("Propimas promedio por tiempo")

# se pagan más propinas en las cenas "noches"
# Out:
# Text(0.5, 1.0, 'Propimas promedio por tiempo')

# %%
#propinas promedio por "fumador"

sns.barplot(data=df, x="smoker", y="tip", errorbar=None)
plt.title("Propinas promedio por fumador/no fumador")

# el hecho de que el cliente fume, no influye en la propina
# Out:
# Text(0.5, 1.0, 'Propinas promedio por fumador/no fumador')

# %% [markdown]
# MULTIVARIADOS

# %%
# Grafico de barras de propinas promedio (Día, Sexo)
sns.barplot(data=df, x="day", y="tip", hue="sex", errorbar=None)
plt.title("Propinas promedio por dia y sexo")
# Out:
# Text(0.5, 1.0, 'Propinas promedio por dia y sexo')

# %%
# Grafico de barras de propinas promedio (tiempo, Sexo)
sns.barplot(data=df, x="time", y="tip", hue="sex", errorbar=None)
plt.title("Propinas promedio por tiempo y sexo")
# Out:
# Text(0.5, 1.0, 'Propinas promedio por tiempo y sexo')

# %%
# Grafico de barras de propinas promedio (fumador, Sexo)
sns.barplot(data=df, x="smoker", y="tip", hue="sex", errorbar=None)
plt.title("Propinas promedio por fumador y sexo")
# Out:
# Text(0.5, 1.0, 'Propinas promedio por fumador y sexo')

# %%
#Grafico de dispersion entre size y tip

sns.barplot(data=df, x="size", y="tip", errorbar=None)
plt.title("Relacion entre tamaño y propinas")
# Out:
# Text(0.5, 1.0, 'Relacion entre tamaño y propinas')
